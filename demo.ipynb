# %%
import numpy as np
import pandas as pd
import torch
from importlib import reload
import edgeNet as en
import matplotlib.pyplot as plt
from torch.utils.data import Dataset, DataLoader
import edgeNet as en
import enet_demo as d

# %%
reload(en)
reload(d)
cfg = [[1, 64,64], [64,64,64], [64, 64, 8]]
bks = en.make_blocks(cfg, batch_norm=True)
net = en.net(bks)
net
# Out:
# net(
#   (bks): Sequential(
#     (0): Sequential(
#       (0): Conv2d(1, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (1): Conv2d(64, 64, kernel_size=(1, 1), stride=(1, 1))
#       (2): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (3): ReLU(inplace)
#     )
#     (1): Sequential(
#       (0): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (1): Conv2d(64, 64, kernel_size=(1, 1), stride=(1, 1))
#       (2): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (3): ReLU(inplace)
#     )
#     (2): Sequential(
#       (0): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (1): Conv2d(64, 8, kernel_size=(1, 1), stride=(1, 1))
#       (2): BatchNorm2d(8, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (3): ReLU(inplace)
#     )
#   )
#   (reduction): Conv2d(8, 2, kernel_size=(1, 1), stride=(1, 1))
# )

# %%
#net to device
model_path = 'edgenet1.pth'
net.load_state_dict(torch.load(model_path))
net.eval()
device = 'cuda:0'
net.to(device)
# Out:
# net(
#   (bks): Sequential(
#     (0): Sequential(
#       (0): Conv2d(1, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (1): Conv2d(64, 64, kernel_size=(1, 1), stride=(1, 1))
#       (2): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (3): ReLU(inplace)
#     )
#     (1): Sequential(
#       (0): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (1): Conv2d(64, 64, kernel_size=(1, 1), stride=(1, 1))
#       (2): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (3): ReLU(inplace)
#     )
#     (2): Sequential(
#       (0): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (1): Conv2d(64, 8, kernel_size=(1, 1), stride=(1, 1))
#       (2): BatchNorm2d(8, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (3): ReLU(inplace)
#     )
#   )
#   (reduction): Conv2d(8, 2, kernel_size=(1, 1), stride=(1, 1))
# )

# %%
reload(d)
video_path = './data/for_demo.mp4'
d.demo(video_path, net)
